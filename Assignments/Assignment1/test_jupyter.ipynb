# %%
from dots_env import Dots
from agent import MinMaxBot, RandomBot
from IPython.display import clear_output
from time import sleep

width = 10
height = 10
node_size = 20
env = Dots(width=width, height=height, node_size=node_size)
# bot = MinMaxBot()
bot = RandomBot(width=width, height=height)


done = False
obs = env.reset()

# %%
while not done:
    actions = bot.compute_action(obs)
    obs, reward, done, info = env.step(actions)
    clear_output()
    env.render(timeout=3000)
    sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a265d8783581> in <module>
#       4     clear_output()
#       5     env.render(timeout=3000)
# ----> 6     sleep(1)
#
# KeyboardInterrupt:
